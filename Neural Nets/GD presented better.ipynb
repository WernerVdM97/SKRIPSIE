# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../Classes')
from GDNN import *
from fileReader import *

# %%
fd = ReadAndProcess('../corpus/bible.txt')
# Out:
# Loading file...
# 8.070080995559692
# Pre-processing...
# 3.0853497982025146

# %%
fd.plot(10)

# %%
net = Net()
net.loadModel('save/28_07')
# Out:
# Net(
#   (fc1): Linear(in_features=2, out_features=3, bias=True)
#   (fc3): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
x = torch.Tensor(20,2)
y = np.zeros(20)
total = fd.N()

for i in range (20):
    x[i] = torch.Tensor([(i/20), 0])
    y[i] = net(x[i])/total

axis = np.linspace(0, 1 ,20)

plt.plot(axis,y)
plt.title("ngrams prob as Cr+1/Cr ratio is increased")
plt.show()

# %% [markdown]
# for r = 0
